# %%
# !pip install "scanpy" \
    "scikit-learn" \
    "numpy"\
    "matplotlib"\
    "seaborn"\
    "scipy"\
    "anndata"\
    "dynamicTreeCut"\
    "wgcna" --upgrade
# Out:
# ...
#   Using cached numpy-2.1.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (60 kB)
# ...
#   Attempting uninstall: wgcna
#     Found existing installation: wgcna 0.3.0
#     Uninstalling wgcna-0.3.0:
#       Successfully uninstalled wgcna-0.3.0
# ...

# %%
import wgcna
import scanpy as sc

adata = sc.read_h5ad("/Users/jameshaberberger/GitHub/29Mar2024_atm_shiny/adata.h5ad")

# %%
microglia = adata[adata.obs["celltype"] == "Microglia"].copy()
microglia = wgcna.common.annotate_gene_groups(microglia)
microglia = wgcna.common.select_genes(microglia, percent_threshold=0.05)
# Out:
# /Users/jameshaberberger/GitHub/wgcna/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/jameshaberberger/GitHub/wgcna/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/jameshaberberger/GitHub/wgcna/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/jameshaberberger/GitHub/wgcna/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/jameshaberberger/GitHub/wgcna/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
# ...

# %%
clustermap, indexer, labels = wgcna.wgcna.run_wgcna(microglia, adjacency_type="signed")
# Out:
# Power: 1, R^2: 0.004706756704101224
# Power: 2, R^2: 0.0004760195158722521
# Power: 3, R^2: 0.07764049377509617
# Power: 4, R^2: 0.3739118237046634
# Power: 5, R^2: 0.34514792590461796
# Power: 6, R^2: 0.2212599760607635
# Power: 7, R^2: 0.25732270035099525
# Power: 8, R^2: 0.2872816209451083
# Power: 9, R^2: 0.25884748841115024
# Power: 10, R^2: 0.4040804613827998
# Power: 11, R^2: 0.5945065379764322
# Power: 12, R^2: 0.7388788360985139
# Power: 13, R^2: 0.7615261937507422
# Power: 14, R^2: nan
# Power: 15, R^2: nan
# Power: 16, R^2: nan
# Power: 17, R^2: nan
# Power: 18, R^2: nan
# Power: 19, R^2: nan
# Power: 20, R^2: nan
# /Users/jameshaberberger/GitHub/wgcna/.venv/lib/python3.12/site-packages/wgcna/connectivity.py:63: RuntimeWarning: divide by zero encountered in log10
#   normalized_p = np.log10(p / p.sum())
# /Users/jameshaberberger/GitHub/wgcna/.venv/lib/python3.12/site-packages/numpy/lib/function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
# ...
